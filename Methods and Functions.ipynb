# %%
mylist = [7,8,6,9]

# %%
mylist
# Out:
# [6, 7, 8, 9]

# %%
mylist.sort()

# %%
mylist.pop(3)
# Out:
# 9

# %%
mylist
# Out:
# [6, 7, 8, 9]

# %%
mylist.pop(3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-96640a582e92> in <module>
# ----> 1 mylist.pop(3)
#
# IndexError: pop index out of range

# %%
help(mylist.insert)
# Out:
# Help on built-in function insert:
#
# insert(...) method of builtins.list instance
#     L.insert(index, object) -- insert object before index

# %%
mylist.insert(3,9)

# %%
mylist
# Out:
# [6, 7, 8, 9]

# %%
5//3
# Out:
# 1

# %%
5%3
# Out:
# 2
